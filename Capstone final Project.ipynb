# %% [markdown]
# ## In this final capstone project, the aim is to cluster neighbourhoods based on their residential profile. To do this, first I load in all the necessary libraries
#
# I also set the Version and ID to get request from Foursquare API further down

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')


CLIENT_ID = 'TTTYSUWFUMJXP00B4DT3JJU0RB4GZ5C25DIEK3EJ2QBMHWK0' # your Foursquare ID
CLIENT_SECRET = 'XU5LCC4PNFPR0JBA41A45ZHHHTAVTTNX1VJUZINIY1X2SF0E' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
# Out:
# Libraries imported.

# %% [markdown]
# ## First I load in the borough and neighbourhood data from NYC

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')

with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
    
neighborhoods_data = newyork_data['features']
# Out:
# Data downloaded!

# %% [markdown]
# ## Next, I create a pandas dataframe and fill it with borough, neighbourhood, latitude and longitude

# %%
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude']

neighborhoods = pd.DataFrame(columns=column_names)

for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %% [markdown]
# ## In the next 2 cells, the important data is loaded from Foursquare API
#
# First I create a function to create a URL which I will need to call multiple times to create instances for every category ID's. The category ID's are all residential building types ranging from hotels to appartments to trailer parks

# %%
def createURL(endpoint, CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, categoryId, limit):
    url = '{}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
            endpoint,
            CLIENT_ID,
            CLIENT_SECRET,
            VERSION,
            lat,
            lng,
            radius,
            categoryId,
            limit
        )
    return url

endpoint = 'https://api.foursquare.com/v2/venues/search?'
categoryIds = ['5032891291d4c4b30a586d68', '4bf58dd8d48988d103941735', '4f2a210c4b9023bd5841ed28',
               '4d954b06a243a5684965b473', '52f2ab2ebcbc57f1066b8b55', '4bf58dd8d48988d1fa931735',
               '4bf58dd8d48988d1f8931735', '4bf58dd8d48988d1ee931735', '56aa371be4b08b9a8d5734e1',
              ]
categoryId = ','.join(categoryIds)
limit = 50

# %%
radius = 1000
def getNearbyResidentialInfo(neighborhoods, latitudes, longitudes, radius):
    endpoint = 'https://api.foursquare.com/v2/venues/search?'
    venues_list = []   
    
    for hood_name, lat, lng in zip(neighborhoods, latitudes, longitudes):
    
        url = createURL(endpoint, CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, categoryId, limit)
        
        results = requests.get(url).json()['response']['venues']

        for item in results:
            venue_name = item['name']
            venue_category = item['categories'][0]['name']
            venue_lat = item['location']['lat']
            venue_lng = item['location']['lng']
            try:
                venue_city = item['location']['city']
            except:
                venue_city = 'N/A'
            venue_state = item['location']['state']
            
            venues_list.append([(hood_name,
                                lat,
                                lng,
                                venue_name,
                                venue_category,
                                venue_lat,
                                venue_lng,
                                venue_city,
                                venue_state
                               )])
            
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood',
                             'Neighborhood Latitude',
                             'Neighborhood Longitude',
                             'Venue Name',
                             'Venue Category',
                             'Venue Latitude',
                             'Venue Longitude',
                             'Venue City',
                             'Venue State'
                            ]
    return nearby_venues

prelim_venue_data = getNearbyResidentialInfo(neighborhoods['Neighborhood'],
                                         neighborhoods['Latitude'],
                                         neighborhoods['Longitude'],
                                         radius
                                        )

# %%
print(prelim_venue_data.shape)
prelim_venue_data.groupby('Venue Category')['Venue Category'].count().sort_values(ascending=False)
# Out:
# (8917, 9)
# Venue Category
# Residential Building (Apartment / Condo)    6261
# Hotel                                       1288
# Housing Development                          639
# Assisted Living                              226
# Bed & Breakfast                               81
# Building                                      76
# Resort                                        65
# Motel                                         59
# Hostel                                        58
# Medical Center                                20
# College Residence Hall                        16
# Boarding House                                11
# Gym                                            8
# Trailer Park                                   8
# Coworking Space                                8
# Other Great Outdoors                           8
# Office                                         7
# Garden                                         7
# Hotel Pool                                     6
# Vacation Rental                                6
# Pool                                           6
# Real Estate Office                             6
# Roof Deck                                      5
# Rehab Center                                   4
# Scenic Lookout                                 4
# Plaza                                          3
# Gym / Fitness Center                           3
# Salon / Barbershop                             3
# General Entertainment                          3
# Event Space                                    3
# Beer Garden                                    2
# Laundry Service                                2
# New American Restaurant                        2
# Pizza Place                                    2
# Professional & Other Places                    2
# Public Art                                     2
# Deli / Bodega                                  1
# Doctor's Office                                1
# Lounge                                         1
# Club House                                     1
# Playground                                     1
# Bakery                                         1
# Airport                                        1
# Name: Venue Category, dtype: int64

# %% [markdown]
# ## After we have sourced the data from the Foursquare API, it needs to be cleaned.
#
# In the cell below I get rid of all categories that are not related to residential buildings, or that do not have a city or neighbourhood assigned to them. The residential categories used for the clustering are 'Residential Building (Apartment / Condo)', 'Hotel', 'Housing Development', 'Assisted Living', 'Bed & Breakfast', 'Motel',
#                             'Hostel', 'College Residence Hall', 'Trailer Park', 'Vacation Rental'

# %%
n_unique = len(prelim_venue_data['Venue Category'].unique())
print(f'There are {n_unique} unique venue categories in this dataframe')

ny_venue_data = prelim_venue_data[(prelim_venue_data['Venue State'] == "New York") | (prelim_venue_data['Venue State'] == "NY")]
ny_venue_data['Venue State'].replace(to_replace="New York", value="NY", inplace=True)
delta = prelim_venue_data.shape[0] - ny_venue_data.shape[0]
print(f'{delta} entries were removed from the preliminary dataset based on "Venue State"')

ny_venue_data.head(5)
ny_venue_data_with_city = ny_venue_data[(ny_venue_data['Venue City'] != "N/A")]
delta = ny_venue_data.shape[0] - ny_venue_data_with_city.shape[0]
print(f'{delta} entries were removed based on "Venue City"')

residential_related_categories = ['Residential Building (Apartment / Condo)', 'Hotel', 'Housing Development', 'Assisted Living', 'Bed & Breakfast', 'Motel',
                            'Hostel', 'College Residence Hall', 'Trailer Park', 'Vacation Rental']
ny_residential_venues = ny_venue_data_with_city[ny_venue_data_with_city['Venue Category'].isin(residential_related_categories)]
delta = ny_venue_data_with_city.shape[0] - ny_residential_venues.shape[0]
print(f'{delta} entries were removed based on "Venue Category" not being related to residential areas')
print(ny_residential_venues['Venue Category'].unique())
ny_residential_venues.head(5)
# Out:
# There are 43 unique venue categories in this dataframe
# 9 entries were removed from the preliminary dataset based on "Venue State"
# 505 entries were removed based on "Venue City"
# 250 entries were removed based on "Venue Category" not being related to residential areas
# ['Housing Development' 'Bed & Breakfast'
#  'Residential Building (Apartment / Condo)' 'Hotel' 'Assisted Living'
#  'Motel' 'Hostel' 'Vacation Rental' 'College Residence Hall'
#  'Trailer Park']
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1    Wakefield              40.894705              -73.847201
# 2    Wakefield              40.894705              -73.847201
# 3    Wakefield              40.894705              -73.847201
# 5    Wakefield              40.894705              -73.847201
# 6    Wakefield              40.894705              -73.847201
#
#                                       Venue Name  \
# 1                        Edenwald Houses - NYCHA
# 2                                    The Chamber
# 3                         741 Hunts Point Avenue
# 5  Andre Camp David (Edendwald Houses Southside)
# 6                              East 238th Street
#
#                              Venue Category  Venue Latitude  Venue Longitude  \
# 1                       Housing Development       40.886606       -73.842116
# 2                           Bed & Breakfast       40.891560       -73.844467
# 3  Residential Building (Apartment / Condo)       40.889555       -73.843807
# 5                       Housing Development       40.885182       -73.844488
# 6  Residential Building (Apartment / Condo)       40.899167       -73.856684
#
#   Venue City Venue State
# 1      Bronx          NY
# 2      Bronx          NY
# 3      Bronx          NY
# 5      Bronx          NY
# 6      Bronx          NY

# %% [markdown]
# ## Now that our dataset is cleansed, we can start counting the amount of residential types per neighbourhood

# %%
ny_venue_category_onehot = pd.get_dummies(ny_residential_venues[['Venue Category']], prefix="", prefix_sep="")

ny_venue_category_onehot['Neighborhood'] = ny_residential_venues['Neighborhood'] 

fixed_columns = [ny_venue_category_onehot.columns[-1]] + list(ny_venue_category_onehot.columns[:-1])
ny_venue_category_onehot = ny_venue_category_onehot[fixed_columns]

print(ny_venue_category_onehot.shape)
venue_counts = ny_venue_category_onehot.groupby('Neighborhood').sum()
venue_counts.head(10)
# Out:
# (8153, 11)
#                    Assisted Living  Bed & Breakfast  College Residence Hall  \
# Neighborhood
# Allerton                         4                2                       0
# Arden Heights                    0                0                       0
# Arlington                        0                0                       0
# Arrochar                         0                0                       0
# Arverne                          0                1                       0
# Astoria                          0                0                       0
# Astoria Heights                  0                0                       0
# Auburndale                       3                0                       0
# Bath Beach                       2                0                       0
# Battery Park City                0                0                       0
#
#                    Hostel  Hotel  Housing Development  Motel  \
# Neighborhood
# Allerton                0      0                   13      1
# Arden Heights           0      0                    2      0
# Arlington               0      0                    2      0
# Arrochar                0      1                    0      0
# Arverne                 0      1                    4      0
# Astoria                 0      1                    2      0
# Astoria Heights         2      4                    0      1
# Auburndale              0      0                    1      0
# Bath Beach              0      1                    0      0
# Battery Park City       0     28                    0      0
#
#                    Residential Building (Apartment / Condo)  Trailer Park  \
# Neighborhood
# Allerton                                                 26             0
# Arden Heights                                             0             0
# Arlington                                                 1             0
# Arrochar                                                  5             0
# Arverne                                                   8             0
# Astoria                                                  44             0
# Astoria Heights                                          12             0
# Auburndale                                                6             0
# Bath Beach                                               35             0
# Battery Park City                                        18             0
#
#                    Vacation Rental
# Neighborhood
# Allerton                         0
# Arden Heights                    0
# Arlington                        0
# Arrochar                         0
# Arverne                          2
# Astoria                          0
# Astoria Heights                  0
# Auburndale                       0
# Bath Beach                       0
# Battery Park City                0

# %% [markdown]
# ## Here we take the venues per neighbourhood and divide them by the total, this way we get the proportion of a certain residential building type per neighbourhood

# %%
venue_totals = {}
for category in residential_related_categories:
    venue_totals[category] = venue_counts[category].sum()

venue_totals



venue_mean = pd.DataFrame()
for category, total in venue_totals.items():
    venue_mean[category] = venue_counts[category].apply(lambda x: x / total)
venue_mean = venue_mean.reindex(sorted(venue_mean.columns), axis=1).reset_index()
venue_mean.head(5)
# Out:
#     Neighborhood  Assisted Living  Bed & Breakfast  College Residence Hall  \
# 0       Allerton         0.018519         0.027778                     0.0
# 1  Arden Heights         0.000000         0.000000                     0.0
# 2      Arlington         0.000000         0.000000                     0.0
# 3       Arrochar         0.000000         0.000000                     0.0
# 4        Arverne         0.000000         0.013889                     0.0
#
#    Hostel     Hotel  Housing Development     Motel  \
# 0     0.0  0.000000             0.020767  0.018182
# 1     0.0  0.000000             0.003195  0.000000
# 2     0.0  0.000000             0.003195  0.000000
# 3     0.0  0.000784             0.000000  0.000000
# 4     0.0  0.000784             0.006390  0.000000
#
#    Residential Building (Apartment / Condo)  Trailer Park  Vacation Rental
# 0                                  0.004459           0.0         0.000000
# 1                                  0.000000           0.0         0.000000
# 2                                  0.000171           0.0         0.000000
# 3                                  0.000857           0.0         0.000000
# 4                                  0.001372           0.0         0.333333

# %% [markdown]
# ## Now that we have the proportion of each neighbourhood residential building per neighbourhood, we can make a top 5 for each neighbourhood

# %%
def return_top_venue_categories(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]



num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Top Venue Category'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Top Venue Category'.format(ind+1))

neighborhoods_top_venue_categories = pd.DataFrame(columns=columns)
neighborhoods_top_venue_categories['Neighborhood'] = venue_mean['Neighborhood']

for ind in np.arange(venue_mean.shape[0]):
    neighborhoods_top_venue_categories.iloc[ind, 1:] = return_top_venue_categories(venue_mean.iloc[ind, :], num_top_venues)

neighborhoods_top_venue_categories.head(5)
# Out:
#     Neighborhood                    1st Top Venue Category  \
# 0       Allerton                           Bed & Breakfast
# 1  Arden Heights                       Housing Development
# 2      Arlington                       Housing Development
# 3       Arrochar  Residential Building (Apartment / Condo)
# 4        Arverne                           Vacation Rental
#
#                      2nd Top Venue Category 3rd Top Venue Category  \
# 0                       Housing Development        Assisted Living
# 1                           Vacation Rental           Trailer Park
# 2  Residential Building (Apartment / Condo)        Vacation Rental
# 3                                     Hotel        Vacation Rental
# 4                           Bed & Breakfast    Housing Development
#
#                      4th Top Venue Category  \
# 0                                     Motel
# 1  Residential Building (Apartment / Condo)
# 2                              Trailer Park
# 3                              Trailer Park
# 4  Residential Building (Apartment / Condo)
#
#                      5th Top Venue Category
# 0  Residential Building (Apartment / Condo)
# 1                                     Motel
# 2                                     Motel
# 3                                     Motel
# 4                                     Hotel

# %% [markdown]
# ## Next we cluster the data based on mean residential types.

# %%
kclusters = 10

venue_grouped_clustering = venue_mean.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(venue_grouped_clustering)

neighborhoods_top_venue_categories.insert(1,'Cluster Labels', kmeans.labels_)

ny_neighborhood_residential_profile = neighborhoods.drop(columns=['Borough'])

ny_neighborhood_residential_profile = ny_neighborhood_residential_profile.join(neighborhoods_top_venue_categories.set_index('Neighborhood'), on='Neighborhood').dropna(axis=0)

ny_neighborhood_residential_profile.head()
# Out:
#   Neighborhood   Latitude  Longitude  Cluster Labels 1st Top Venue Category  \
# 0    Wakefield  40.894705 -73.847201             0.0        Bed & Breakfast
# 1   Co-op City  40.874294 -73.829939             5.0        Assisted Living
# 2  Eastchester  40.887556 -73.827806             5.0        Assisted Living
# 3    Fieldston  40.895437 -73.905643             8.0                  Motel
# 4    Riverdale  40.890834 -73.912585             5.0        Assisted Living
#
#                      2nd Top Venue Category  \
# 0                       Housing Development
# 1  Residential Building (Apartment / Condo)
# 2                                     Hotel
# 3                           Assisted Living
# 4  Residential Building (Apartment / Condo)
#
#                      3rd Top Venue Category 4th Top Venue Category  \
# 0  Residential Building (Apartment / Condo)        Vacation Rental
# 1                                     Hotel        Vacation Rental
# 2  Residential Building (Apartment / Condo)        Vacation Rental
# 3  Residential Building (Apartment / Condo)    Housing Development
# 4                           Vacation Rental           Trailer Park
#
#   5th Top Venue Category
# 0           Trailer Park
# 1           Trailer Park
# 2           Trailer Park
# 3        Vacation Rental
# 4                  Motel

# %% [markdown]
# ## Down below is the most interesting part of the project! a visualisation of the clusters on a map of NYC
# ## The image will not load on github, so the visualisation will be available in the report

# %%
latitude = 40.730610
longitude = -73.935242
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(ny_neighborhood_residential_profile['Latitude'], ny_neighborhood_residential_profile['Longitude'], ny_neighborhood_residential_profile['Neighborhood'], ny_neighborhood_residential_profile['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Lastly we can analyse the clusters, this will be expanded on in the report

# %%
for cluster in range(0, kclusters):
    print(f'Cluster {cluster}:')
    print(ny_neighborhood_residential_profile.loc[ny_neighborhood_residential_profile['Cluster Labels'] == cluster, ny_neighborhood_residential_profile.columns[[0] + list(range(4, ny_neighborhood_residential_profile.shape[1]))]], end="\n\n\n")
# Out:
# Cluster 0:
#           Neighborhood 1st Top Venue Category  \
# 0            Wakefield        Bed & Breakfast
# 11      Pelham Parkway        Bed & Breakfast
# 30         Parkchester        Bed & Breakfast
# 35      Spuyten Duyvil        Bed & Breakfast
# 44           Unionport        Bed & Breakfast
# 46           Bay Ridge        Bed & Breakfast
# 48         Sunset Park        Bed & Breakfast
# 56       East Flatbush        Bed & Breakfast
# 57          Kensington        Bed & Breakfast
# 58     Windsor Terrace        Bed & Breakfast
# 62            Bushwick        Bed & Breakfast
# 99       Fort Hamilton        Bed & Breakfast
# 137      Richmond Hill        Bed & Breakfast
# 141      East Elmhurst        Bed & Breakfast
# 143          Ridgewood        Bed & Breakfast
# 155          Glen Oaks        Bed & Breakfast
# 171      Broad Channel        Bed & Breakfast
# 178     Rockaway Beach        Bed & Breakfast
# 181        Floral Park        Bed & Breakfast
# 191      Rockaway Park        Bed & Breakfast
# 194           Bellaire        Bed & Breakfast
# 205      Port Richmond        Bed & Breakfast
# 219        Silver Lake        Bed & Breakfast
# 221        Ditmas Park        Bed & Breakfast
# 240          Rossville        Bed & Breakfast
# 275    Stuyvesant Town        Bed & Breakfast
# 282  Broadway Junction    Housing Development
# 298           Allerton        Bed & Breakfast
# 305          Fox Hills        Bed & Breakfast
#
#                        2nd Top Venue Category  \
# 0                         Housing Development
# 11                            Assisted Living
# 30   Residential Building (Apartment / Condo)
# 35                            Assisted Living
# 44                            Assisted Living
# 46   Residential Building (Apartment / Condo)
# 48                            Assisted Living
# 56                        Housing Development
# 57   Residential Building (Apartment / Condo)
# 58   Residential Building (Apartment / Condo)
# 62                            Assisted Living
# 99   Residential Building (Apartment / Condo)
# 137  Residential Building (Apartment / Condo)
# 141                                     Hotel
# 143  Residential Building (Apartment / Condo)
# 155                       Housing Development
# 171  Residential Building (Apartment / Condo)
# 178  Residential Building (Apartment / Condo)
# 181                       Housing Development
# 191                       Housing Development
# 194                           Assisted Living
# 205                           Assisted Living
# 219                           Assisted Living
# 221  Residential Building (Apartment / Condo)
# 240                           Assisted Living
# 275  Residential Building (Apartment / Condo)
# 282                           Bed & Breakfast
# 298                       Housing Development
# 305                       Housing Development
#
#                        3rd Top Venue Category  \
# 0    Residential Building (Apartment / Condo)
# 11   Residential Building (Apartment / Condo)
# 30                            Assisted Living
# 35   Residential Building (Apartment / Condo)
# 44   Residential Building (Apartment / Condo)
# 46                        Housing Development
# 48                                      Hotel
# 56   Residential Building (Apartment / Condo)
# 57                            Assisted Living
# 58                            Assisted Living
# 62   Residential Building (Apartment / Condo)
# 99                        Housing Development
# 137                           Assisted Living
# 141                           Assisted Living
# 143                           Assisted Living
# 155  Residential Building (Apartment / Condo)
# 171                           Vacation Rental
# 178                       Housing Development
# 181  Residential Building (Apartment / Condo)
# 191  Residential Building (Apartment / Condo)
# 194                       Housing Development
# 205                       Housing Development
# 219                       Housing Development
# 221                           Vacation Rental
# 240                       Housing Development
# 275                       Housing Development
# 282                           Assisted Living
# 298                           Assisted Living
# 305                           Assisted Living
#
#                        4th Top Venue Category  \
# 0                             Vacation Rental
# 11                        Housing Development
# 30                        Housing Development
# 35                        Housing Development
# 44                        Housing Development
# 46                                      Hotel
# 48   Residential Building (Apartment / Condo)
# 56                                      Hotel
# 57                                      Hotel
# 58                        Housing Development
# 62                                      Hotel
# 99                                      Hotel
# 137                       Housing Development
# 141  Residential Building (Apartment / Condo)
# 143                                     Hotel
# 155                           Vacation Rental
# 171                              Trailer Park
# 178                                     Hotel
# 181                           Vacation Rental
# 191                           Vacation Rental
# 194  Residential Building (Apartment / Condo)
# 205  Residential Building (Apartment / Condo)
# 219  Residential Building (Apartment / Condo)
# 221                              Trailer Park
# 240  Residential Building (Apartment / Condo)
# 275                                     Hotel
# 282  Residential Building (Apartment / Condo)
# 298                                     Motel
# 305  Residential Building (Apartment / Condo)
#
#                        5th Top Venue Category
# 0                                Trailer Park
# 11                                      Hotel
# 30                            Vacation Rental
# 35                                      Hotel
# 44                            Vacation Rental
# 46                            Vacation Rental
# 48                            Vacation Rental
# 56                            Vacation Rental
# 57                            Vacation Rental
# 58                            Vacation Rental
# 62                        Housing Development
# 99                            Vacation Rental
# 137                           Vacation Rental
# 141                       Housing Development
# 143                           Vacation Rental
# 155                              Trailer Park
# 171                                     Motel
# 178                           Vacation Rental
# 181                              Trailer Park
# 191                              Trailer Park
# 194                           Vacation Rental
# 205                           Vacation Rental
# 219                                     Hotel
# 221                                     Motel
# 240                           Vacation Rental
# 275                           Vacation Rental
# 282                                     Hotel
# 298  Residential Building (Apartment / Condo)
# 305                                     Hotel
#
#
# Cluster 1:
#     Neighborhood 1st Top Venue Category 2nd Top Venue Category  \
# 177      Arverne        Vacation Rental        Bed & Breakfast
# 192   Somerville        Vacation Rental        Bed & Breakfast
#
#     3rd Top Venue Category                    4th Top Venue Category  \
# 177    Housing Development  Residential Building (Apartment / Condo)
# 192    Housing Development  Residential Building (Apartment / Condo)
#
#     5th Top Venue Category
# 177                  Hotel
# 192           Trailer Park
#
#
# Cluster 2:
#            Neighborhood 1st Top Venue Category  \
# 63   Bedford Stuyvesant           Trailer Park
# 71        Cypress Hills           Trailer Park
# 90            City Line           Trailer Park
# 146           Woodhaven           Trailer Park
# 197          St. George           Trailer Park
# 198        New Brighton           Trailer Park
# 218       Tompkinsville           Trailer Park
# 256       Randall Manor           Trailer Park
#
#                        2nd Top Venue Category  \
# 63                            Bed & Breakfast
# 71                                     Hostel
# 90                                     Hostel
# 146  Residential Building (Apartment / Condo)
# 197                       Housing Development
# 198                       Housing Development
# 218                           Assisted Living
# 256                           Assisted Living
#
#                        3rd Top Venue Category  \
# 63                                     Hostel
# 71                        Housing Development
# 90                                      Motel
# 146                       Housing Development
# 197                           Assisted Living
# 198                           Assisted Living
# 218                       Housing Development
# 256  Residential Building (Apartment / Condo)
#
#                        4th Top Venue Category  \
# 63                        Housing Development
# 71   Residential Building (Apartment / Condo)
# 90                        Housing Development
# 146                           Vacation Rental
# 197  Residential Building (Apartment / Condo)
# 198  Residential Building (Apartment / Condo)
# 218  Residential Building (Apartment / Condo)
# 256                       Housing Development
#
#                        5th Top Venue Category
# 63   Residential Building (Apartment / Condo)
# 71                            Vacation Rental
# 90   Residential Building (Apartment / Condo)
# 146                                     Motel
# 197                                     Hotel
# 198                                     Hotel
# 218                                     Hotel
# 256                           Vacation Rental
#
#
# Cluster 3:
#           Neighborhood  1st Top Venue Category  2nd Top Venue Category  \
# 54            Flatbush  College Residence Hall         Bed & Breakfast
# 92             Midwood  College Residence Hall         Bed & Breakfast
# 100          Chinatown  College Residence Hall                   Hotel
# 104     Manhattanville  College Residence Hall         Bed & Breakfast
# 112     Lincoln Square  College Residence Hall                   Hotel
# 117  Greenwich Village  College Residence Hall                   Hotel
# 120            Tribeca  College Residence Hall                   Hotel
# 121       Little Italy  College Residence Hall                   Hotel
# 122               Soho  College Residence Hall                   Hotel
# 124   Manhattan Valley                  Hostel  College Residence Hall
# 183    Jamaica Estates  College Residence Hall                  Hostel
# 185          Hillcrest  College Residence Hall     Housing Development
#
#                        3rd Top Venue Category  \
# 54                            Assisted Living
# 92                            Assisted Living
# 100  Residential Building (Apartment / Condo)
# 104                                    Hostel
# 112  Residential Building (Apartment / Condo)
# 117  Residential Building (Apartment / Condo)
# 120  Residential Building (Apartment / Condo)
# 121  Residential Building (Apartment / Condo)
# 122  Residential Building (Apartment / Condo)
# 124  Residential Building (Apartment / Condo)
# 183                       Housing Development
# 185  Residential Building (Apartment / Condo)
#
#                        4th Top Venue Category 5th Top Venue Category
# 54   Residential Building (Apartment / Condo)        Vacation Rental
# 92   Residential Building (Apartment / Condo)    Housing Development
# 100                           Vacation Rental           Trailer Park
# 104  Residential Building (Apartment / Condo)    Housing Development
# 112                           Vacation Rental           Trailer Park
# 117                           Vacation Rental           Trailer Park
# 120                           Vacation Rental           Trailer Park
# 121                           Vacation Rental           Trailer Park
# 122                           Vacation Rental           Trailer Park
# 124                                     Hotel    Housing Development
# 183  Residential Building (Apartment / Condo)                  Hotel
# 185                           Vacation Rental           Trailer Park
#
#
# Cluster 4:
#        Neighborhood 1st Top Venue Category 2nd Top Venue Category  \
# 51   Brighton Beach        Vacation Rental                 Hostel
# 302         Hammels        Vacation Rental    Housing Development
#
#                        3rd Top Venue Category  \
# 51                            Assisted Living
# 302  Residential Building (Apartment / Condo)
#
#                        4th Top Venue Category 5th Top Venue Category
# 51   Residential Building (Apartment / Condo)    Housing Development
# 302                              Trailer Park                  Motel
#
#
# Cluster 5:
#                   Neighborhood                    1st Top Venue Category  \
# 1                   Co-op City                           Assisted Living
# 2                  Eastchester                           Assisted Living
# 4                    Riverdale                           Assisted Living
# 5                  Kingsbridge                           Assisted Living
# 6                  Marble Hill                           Assisted Living
# 12                 City Island                       Housing Development
# 14          University Heights  Residential Building (Apartment / Condo)
# 15              Morris Heights                           Assisted Living
# 16                     Fordham                           Assisted Living
# 17                East Tremont                       Housing Development
# 18                  West Farms                       Housing Development
# 19                High  Bridge  Residential Building (Apartment / Condo)
# 20                     Melrose                       Housing Development
# 21                  Mott Haven                       Housing Development
# 22                 Port Morris                       Housing Development
# 23                    Longwood                       Housing Development
# 24                 Hunts Point                           Assisted Living
# 25                  Morrisania                       Housing Development
# 26                   Soundview                       Housing Development
# 27                Clason Point                       Housing Development
# 28                 Throgs Neck                       Housing Development
# 29                Country Club                       Housing Development
# 31          Westchester Square  Residential Building (Apartment / Condo)
# 32                    Van Nest                           Assisted Living
# 33                 Morris Park  Residential Building (Apartment / Condo)
# 37                  Pelham Bay  Residential Building (Apartment / Condo)
# 38               Schuylerville                       Housing Development
# 39              Edgewater Park                       Housing Development
# 43                   Concourse                           Assisted Living
# 49                  Greenpoint                                     Hotel
# 50                   Gravesend                           Assisted Living
# 53           Manhattan Terrace                           Assisted Living
# 59            Prospect Heights  Residential Building (Apartment / Condo)
# 60                 Brownsville                       Housing Development
# 64            Brooklyn Heights                                     Hotel
# 69                 Fort Greene  Residential Building (Apartment / Condo)
# 70                  Park Slope  Residential Building (Apartment / Condo)
# 72               East New York                       Housing Development
# 74                    Canarsie                       Housing Development
# 75                   Flatlands                       Housing Development
# 76                 Mill Island                           Assisted Living
# 78                Coney Island                       Housing Development
# 79                  Bath Beach                           Assisted Living
# 83                 Marine Park                       Housing Development
# 85                    Sea Gate                       Housing Development
# 86                    Downtown                                     Hotel
# 87                 Boerum Hill                                     Hotel
# 88   Prospect Lefferts Gardens  Residential Building (Apartment / Condo)
# 91                Bergen Beach  Residential Building (Apartment / Condo)
# 93         Prospect Park South  Residential Building (Apartment / Condo)
# 94                  Georgetown                       Housing Development
# 98               Ocean Parkway                           Assisted Living
# 101         Washington Heights  Residential Building (Apartment / Condo)
# 102                     Inwood  Residential Building (Apartment / Condo)
# 106                East Harlem                       Housing Development
# 107            Upper East Side  Residential Building (Apartment / Condo)
# 108                  Yorkville  Residential Building (Apartment / Condo)
# 109                 Lenox Hill                                     Hotel
# 110           Roosevelt Island                                     Hotel
# 111            Upper West Side                                     Hotel
# 118               East Village                                     Hotel
# 119            Lower East Side                                     Hotel
# 129                    Astoria  Residential Building (Apartment / Condo)
# 131            Jackson Heights  Residential Building (Apartment / Condo)
# 134                     Corona  Residential Building (Apartment / Condo)
# 135               Forest Hills                           Assisted Living
# 136                Kew Gardens  Residential Building (Apartment / Condo)
# 142                    Maspeth                           Assisted Living
# 144                   Glendale                           Assisted Living
# 145                  Rego Park  Residential Building (Apartment / Condo)
# 147                 Ozone Park                                     Hotel
# 148           South Ozone Park                                     Hotel
# 149              College Point                       Housing Development
# 150                 Whitestone                           Assisted Living
# 151                    Bayside                           Assisted Living
# 152                 Auburndale                           Assisted Living
# 153                Little Neck                           Assisted Living
# 154                 Douglaston                           Assisted Living
# 158              Fresh Meadows                                     Hotel
# 160             Jamaica Center  Residential Building (Apartment / Condo)
# 162             Queens Village                       Housing Development
# 163                     Hollis                           Assisted Living
# 164              South Jamaica                           Assisted Living
# 165                 St. Albans                           Assisted Living
# 166                   Rochdale                       Housing Development
# 167        Springfield Gardens                           Assisted Living
# 169                   Rosedale                       Housing Development
# 170               Far Rockaway                           Assisted Living
# 172               Breezy Point  Residential Building (Apartment / Condo)
# 174                 Beechhurst                           Assisted Living
# 175                Bay Terrace                       Housing Development
# 176                   Edgemere                       Housing Development
# 179                   Neponsit                       Housing Development
# 182                 Holliswood                           Assisted Living
# 184            Queensboro Hill                           Assisted Living
# 187                 Lindenwood                       Housing Development
# 188                  Laurelton  Residential Building (Apartment / Condo)
# 190               Belle Harbor                       Housing Development
# 193                 Brookville                       Housing Development
# 195               North Corona                                     Hotel
# 196       Forest Hills Gardens  Residential Building (Apartment / Condo)
# 199                  Stapleton                       Housing Development
# 200                   Rosebank                       Housing Development
# 201              West Brighton                           Assisted Living
# 202                Grymes Hill                           Assisted Living
# 203                  Todt Hill  Residential Building (Apartment / Condo)
# 204                South Beach                       Housing Development
# 206           Mariner's Harbor  Residential Building (Apartment / Condo)
# 207                 Port Ivory  Residential Building (Apartment / Condo)
# 208          Castleton Corners                           Assisted Living
# 209            New Springville  Residential Building (Apartment / Condo)
# 211                   New Dorp                       Housing Development
# 212                    Oakwood                       Housing Development
# 213                Great Kills                       Housing Development
# 214                Eltingville                       Housing Development
# 216                    Woodrow                           Assisted Living
# 217                Tottenville  Residential Building (Apartment / Condo)
# 222                    Wingate  Residential Building (Apartment / Condo)
# 223                      Rugby                       Housing Development
# 225                Westerleigh                       Housing Development
# 226               Graniteville                       Housing Development
# 227                  Arlington                       Housing Development
# 228                   Arrochar  Residential Building (Apartment / Condo)
# 229                   Grasmere  Residential Building (Apartment / Condo)
# 230                   Old Town  Residential Building (Apartment / Condo)
# 231               Dongan Hills                       Housing Development
# 235                Bay Terrace                       Housing Development
# 239                 Charleston                       Housing Development
# 241              Arden Heights                       Housing Development
# 242                 Greenridge                                     Hotel
# 245                 Bloomfield                                     Hotel
# 246                 Bulls Head                           Assisted Living
# 247              Carnegie Hill  Residential Building (Apartment / Condo)
# 251              Richmond Town  Residential Building (Apartment / Condo)
# 252                Shore Acres                           Assisted Living
# 253                    Clifton                           Assisted Living
# 258                   Elm Park  Residential Building (Apartment / Condo)
# 261            Paerdegat Basin  Residential Building (Apartment / Condo)
# 262                 Mill Basin                           Assisted Living
# 264                     Utopia                       Housing Development
# 265                    Pomonok                       Housing Development
# 267          Claremont Village                       Housing Development
# 268          Concourse Village                       Housing Development
# 270                 Mount Hope                           Assisted Living
# 278                 Blissville                                     Hotel
# 279               Fulton Ferry                                     Hotel
# 280               Vinegar Hill  Residential Building (Apartment / Condo)
# 283                      Dumbo                       Housing Development
# 284              Manor Heights                           Assisted Living
# 285                Willowbrook                           Assisted Living
# 286               Sandy Ground                       Housing Development
# 289                  Homecrest                           Assisted Living
# 290             Middle Village  Residential Building (Apartment / Condo)
# 294                      Malba                           Assisted Living
# 295              Highland Park                           Assisted Living
# 296                    Madison  Residential Building (Apartment / Condo)
# 297                  Bronxdale                           Assisted Living
# 299        Kingsbridge Heights                           Assisted Living
# 300                    Erasmus  Residential Building (Apartment / Condo)
# 303                  Bayswater                                     Hotel
#
#                        2nd Top Venue Category  \
# 1    Residential Building (Apartment / Condo)
# 2                                       Hotel
# 4    Residential Building (Apartment / Condo)
# 5                         Housing Development
# 6                         Housing Development
# 12   Residential Building (Apartment / Condo)
# 14                        Housing Development
# 15   Residential Building (Apartment / Condo)
# 16   Residential Building (Apartment / Condo)
# 17   Residential Building (Apartment / Condo)
# 18   Residential Building (Apartment / Condo)
# 19                        Housing Development
# 20                            Assisted Living
# 21   Residential Building (Apartment / Condo)
# 22   Residential Building (Apartment / Condo)
# 23                            Assisted Living
# 24                        Housing Development
# 25                            Assisted Living
# 26                            Assisted Living
# 27   Residential Building (Apartment / Condo)
# 28   Residential Building (Apartment / Condo)
# 29   Residential Building (Apartment / Condo)
# 31                        Housing Development
# 32   Residential Building (Apartment / Condo)
# 33                                      Hotel
# 37                        Housing Development
# 38   Residential Building (Apartment / Condo)
# 39   Residential Building (Apartment / Condo)
# 43   Residential Building (Apartment / Condo)
# 49   Residential Building (Apartment / Condo)
# 50   Residential Building (Apartment / Condo)
# 53   Residential Building (Apartment / Condo)
# 59                        Housing Development
# 60   Residential Building (Apartment / Condo)
# 64   Residential Building (Apartment / Condo)
# 69                                      Hotel
# 70                                      Hotel
# 72                            Assisted Living
# 74                                      Hotel
# 75                                      Hotel
# 76                            Vacation Rental
# 78   Residential Building (Apartment / Condo)
# 79   Residential Building (Apartment / Condo)
# 83   Residential Building (Apartment / Condo)
# 85   Residential Building (Apartment / Condo)
# 86   Residential Building (Apartment / Condo)
# 87   Residential Building (Apartment / Condo)
# 88                            Assisted Living
# 91                            Vacation Rental
# 93                            Vacation Rental
# 94                                      Hotel
# 98   Residential Building (Apartment / Condo)
# 101                           Vacation Rental
# 102                                     Hotel
# 106  Residential Building (Apartment / Condo)
# 107                                     Hotel
# 108                                     Hotel
# 109  Residential Building (Apartment / Condo)
# 110  Residential Building (Apartment / Condo)
# 111  Residential Building (Apartment / Condo)
# 118  Residential Building (Apartment / Condo)
# 119  Residential Building (Apartment / Condo)
# 129                       Housing Development
# 131                           Vacation Rental
# 134                           Assisted Living
# 135  Residential Building (Apartment / Condo)
# 136                           Assisted Living
# 142                                     Hotel
# 144  Residential Building (Apartment / Condo)
# 145                                     Hotel
# 147  Residential Building (Apartment / Condo)
# 148                           Assisted Living
# 149                                     Hotel
# 150                                     Hotel
# 151  Residential Building (Apartment / Condo)
# 152                       Housing Development
# 153  Residential Building (Apartment / Condo)
# 154                                     Hotel
# 158                       Housing Development
# 160                                     Hotel
# 162                                     Hotel
# 163                       Housing Development
# 164                                     Hotel
# 165                                     Hotel
# 166                                     Hotel
# 167                       Housing Development
# 169                                     Hotel
# 170  Residential Building (Apartment / Condo)
# 172                           Vacation Rental
# 174  Residential Building (Apartment / Condo)
# 175  Residential Building (Apartment / Condo)
# 176  Residential Building (Apartment / Condo)
# 179                           Vacation Rental
# 182  Residential Building (Apartment / Condo)
# 184  Residential Building (Apartment / Condo)
# 187                                     Hotel
# 188                           Vacation Rental
# 190  Residential Building (Apartment / Condo)
# 193  Residential Building (Apartment / Condo)
# 195  Residential Building (Apartment / Condo)
# 196                           Assisted Living
# 199                           Assisted Living
# 200                           Assisted Living
# 201  Residential Building (Apartment / Condo)
# 202  Residential Building (Apartment / Condo)
# 203                           Vacation Rental
# 204                           Vacation Rental
# 206                           Vacation Rental
# 207                           Vacation Rental
# 208  Residential Building (Apartment / Condo)
# 209                           Vacation Rental
# 211  Residential Building (Apartment / Condo)
# 212  Residential Building (Apartment / Condo)
# 213                                     Hotel
# 214                                     Hotel
# 216                       Housing Development
# 217                           Vacation Rental
# 222                       Housing Development
# 223  Residential Building (Apartment / Condo)
# 225  Residential Building (Apartment / Condo)
# 226                                     Hotel
# 227  Residential Building (Apartment / Condo)
# 228                                     Hotel
# 229                                     Hotel
# 230                                     Hotel
# 231  Residential Building (Apartment / Condo)
# 235  Residential Building (Apartment / Condo)
# 239                                     Hotel
# 241                           Vacation Rental
# 242  Residential Building (Apartment / Condo)
# 245                           Vacation Rental
# 246                       Housing Development
# 247                                     Hotel
# 251                           Vacation Rental
# 252                       Housing Development
# 253                       Housing Development
# 258                           Vacation Rental
# 261                           Vacation Rental
# 262                                     Hotel
# 264                                     Hotel
# 265  Residential Building (Apartment / Condo)
# 267                           Assisted Living
# 268                           Assisted Living
# 270                       Housing Development
# 278  Residential Building (Apartment / Condo)
# 279  Residential Building (Apartment / Condo)
# 280                                     Hotel
# 283  Residential Building (Apartment / Condo)
# 284  Residential Building (Apartment / Condo)
# 285                                     Hotel
# 286  Residential Building (Apartment / Condo)
# 289  Residential Building (Apartment / Condo)
# 290                           Vacation Rental
# 294                                     Hotel
# 295  Residential Building (Apartment / Condo)
# 296                       Housing Development
# 297  Residential Building (Apartment / Condo)
# 299                       Housing Development
# 300                           Assisted Living
# 303                           Vacation Rental
#
#                        3rd Top Venue Category  \
# 1                                       Hotel
# 2    Residential Building (Apartment / Condo)
# 4                             Vacation Rental
# 5    Residential Building (Apartment / Condo)
# 6    Residential Building (Apartment / Condo)
# 12                            Vacation Rental
# 14                            Vacation Rental
# 15                        Housing Development
# 16                        Housing Development
# 17                            Assisted Living
# 18                            Assisted Living
# 19                            Assisted Living
# 20   Residential Building (Apartment / Condo)
# 21                            Assisted Living
# 22                            Vacation Rental
# 23   Residential Building (Apartment / Condo)
# 24   Residential Building (Apartment / Condo)
# 25   Residential Building (Apartment / Condo)
# 26   Residential Building (Apartment / Condo)
# 27                            Vacation Rental
# 28                            Vacation Rental
# 29                                      Hotel
# 31                                      Hotel
# 32                        Housing Development
# 33                            Vacation Rental
# 37                                      Hotel
# 38                            Vacation Rental
# 39                            Vacation Rental
# 43                        Housing Development
# 49                            Assisted Living
# 50                        Housing Development
# 53                        Housing Development
# 59                                      Hotel
# 60                                      Hotel
# 64                        Housing Development
# 69                        Housing Development
# 70                            Vacation Rental
# 72   Residential Building (Apartment / Condo)
# 74   Residential Building (Apartment / Condo)
# 75   Residential Building (Apartment / Condo)
# 76                               Trailer Park
# 78                            Vacation Rental
# 79                                      Hotel
# 83                                      Hotel
# 85                            Vacation Rental
# 86                            Vacation Rental
# 87                            Vacation Rental
# 88                            Vacation Rental
# 91                               Trailer Park
# 93                               Trailer Park
# 94   Residential Building (Apartment / Condo)
# 98                        Housing Development
# 101                              Trailer Park
# 102                           Vacation Rental
# 106                                     Hotel
# 107                           Vacation Rental
# 108                       Housing Development
# 109                           Vacation Rental
# 110                       Housing Development
# 111                           Vacation Rental
# 118                           Assisted Living
# 119                       Housing Development
# 129                                     Hotel
# 131                              Trailer Park
# 134                                     Hotel
# 135                       Housing Development
# 136                                     Hotel
# 142  Residential Building (Apartment / Condo)
# 144                           Vacation Rental
# 145                           Vacation Rental
# 147                           Vacation Rental
# 148  Residential Building (Apartment / Condo)
# 149  Residential Building (Apartment / Condo)
# 150  Residential Building (Apartment / Condo)
# 151                       Housing Development
# 152  Residential Building (Apartment / Condo)
# 153                                     Hotel
# 154  Residential Building (Apartment / Condo)
# 158  Residential Building (Apartment / Condo)
# 160                       Housing Development
# 162  Residential Building (Apartment / Condo)
# 163  Residential Building (Apartment / Condo)
# 164  Residential Building (Apartment / Condo)
# 165  Residential Building (Apartment / Condo)
# 166  Residential Building (Apartment / Condo)
# 167  Residential Building (Apartment / Condo)
# 169  Residential Building (Apartment / Condo)
# 170                       Housing Development
# 172                              Trailer Park
# 174                           Vacation Rental
# 175                                     Hotel
# 176                                     Hotel
# 179                              Trailer Park
# 182                       Housing Development
# 184                       Housing Development
# 187  Residential Building (Apartment / Condo)
# 188                              Trailer Park
# 190                           Vacation Rental
# 193                           Vacation Rental
# 195                           Vacation Rental
# 196                                     Hotel
# 199  Residential Building (Apartment / Condo)
# 200  Residential Building (Apartment / Condo)
# 201                       Housing Development
# 202                       Housing Development
# 203                              Trailer Park
# 204                              Trailer Park
# 206                              Trailer Park
# 207                              Trailer Park
# 208                           Vacation Rental
# 209                              Trailer Park
# 211                           Vacation Rental
# 212                           Vacation Rental
# 213  Residential Building (Apartment / Condo)
# 214  Residential Building (Apartment / Condo)
# 216                           Vacation Rental
# 217                              Trailer Park
# 222                           Vacation Rental
# 223                           Vacation Rental
# 225                           Vacation Rental
# 226  Residential Building (Apartment / Condo)
# 227                           Vacation Rental
# 228                           Vacation Rental
# 229                           Vacation Rental
# 230                           Vacation Rental
# 231                           Vacation Rental
# 235                                     Hotel
# 239                           Vacation Rental
# 241                              Trailer Park
# 242                           Vacation Rental
# 245                              Trailer Park
# 246                                     Hotel
# 247                           Vacation Rental
# 251                              Trailer Park
# 252                                     Hotel
# 253  Residential Building (Apartment / Condo)
# 258                              Trailer Park
# 261                              Trailer Park
# 262  Residential Building (Apartment / Condo)
# 264  Residential Building (Apartment / Condo)
# 265                           Vacation Rental
# 267  Residential Building (Apartment / Condo)
# 268  Residential Building (Apartment / Condo)
# 270  Residential Building (Apartment / Condo)
# 278                       Housing Development
# 279                       Housing Development
# 280                       Housing Development
# 283                                     Hotel
# 284                           Vacation Rental
# 285                           Vacation Rental
# 286                           Vacation Rental
# 289                       Housing Development
# 290                              Trailer Park
# 294  Residential Building (Apartment / Condo)
# 295                           Vacation Rental
# 296                                     Hotel
# 297                       Housing Development
# 299  Residential Building (Apartment / Condo)
# 300                       Housing Development
# 303                              Trailer Park
#
#                        4th Top Venue Category  \
# 1                             Vacation Rental
# 2                             Vacation Rental
# 4                                Trailer Park
# 5                                       Hotel
# 6                                       Hotel
# 12                               Trailer Park
# 14                               Trailer Park
# 15                                      Hotel
# 16                                      Hotel
# 17                                      Hotel
# 18                                      Hotel
# 19                                      Hotel
# 20                                      Hotel
# 21                                      Hotel
# 22                               Trailer Park
# 23                            Vacation Rental
# 24                            Vacation Rental
# 25                                      Hotel
# 26                            Vacation Rental
# 27                               Trailer Park
# 28                               Trailer Park
# 29                            Vacation Rental
# 31                            Vacation Rental
# 32                            Vacation Rental
# 33                               Trailer Park
# 37                            Vacation Rental
# 38                               Trailer Park
# 39                               Trailer Park
# 43                                      Hotel
# 49                        Housing Development
# 50                            Vacation Rental
# 53                                      Hotel
# 59                            Vacation Rental
# 60                            Vacation Rental
# 64                            Vacation Rental
# 69                            Vacation Rental
# 70                               Trailer Park
# 72                                      Hotel
# 74                            Vacation Rental
# 75                            Vacation Rental
# 76   Residential Building (Apartment / Condo)
# 78                               Trailer Park
# 79                            Vacation Rental
# 83                            Vacation Rental
# 85                               Trailer Park
# 86                               Trailer Park
# 87                               Trailer Park
# 88                               Trailer Park
# 91                                      Motel
# 93                                      Motel
# 94                            Vacation Rental
# 98                                      Hotel
# 101                                     Motel
# 102                              Trailer Park
# 106                           Vacation Rental
# 107                              Trailer Park
# 108                           Vacation Rental
# 109                              Trailer Park
# 110                           Vacation Rental
# 111                              Trailer Park
# 118                       Housing Development
# 119                           Assisted Living
# 129                           Vacation Rental
# 131                                     Motel
# 134                       Housing Development
# 135                           Vacation Rental
# 136                           Vacation Rental
# 142                           Vacation Rental
# 144                              Trailer Park
# 145                              Trailer Park
# 147                              Trailer Park
# 148                           Vacation Rental
# 149                           Vacation Rental
# 150                           Vacation Rental
# 151                                     Hotel
# 152                           Vacation Rental
# 153                           Vacation Rental
# 154                           Vacation Rental
# 158                           Vacation Rental
# 160                           Vacation Rental
# 162                           Vacation Rental
# 163                           Vacation Rental
# 164                           Vacation Rental
# 165                           Vacation Rental
# 166                           Vacation Rental
# 167                           Vacation Rental
# 169                           Vacation Rental
# 170                                     Hotel
# 172                                     Motel
# 174                              Trailer Park
# 175                           Vacation Rental
# 176                           Vacation Rental
# 179  Residential Building (Apartment / Condo)
# 182                           Vacation Rental
# 184                           Vacation Rental
# 187                           Vacation Rental
# 188                                     Motel
# 190                              Trailer Park
# 193                              Trailer Park
# 195                              Trailer Park
# 196                           Vacation Rental
# 199                                     Hotel
# 200                                     Hotel
# 201                           Vacation Rental
# 202                                     Hotel
# 203                                     Motel
# 204  Residential Building (Apartment / Condo)
# 206                                     Motel
# 207                                     Motel
# 208                              Trailer Park
# 209                                     Motel
# 211                              Trailer Park
# 212                              Trailer Park
# 213                           Vacation Rental
# 214                           Vacation Rental
# 216                              Trailer Park
# 217                                     Motel
# 222                              Trailer Park
# 223                              Trailer Park
# 225                              Trailer Park
# 226                           Vacation Rental
# 227                              Trailer Park
# 228                              Trailer Park
# 229                              Trailer Park
# 230                              Trailer Park
# 231                              Trailer Park
# 235                           Vacation Rental
# 239                              Trailer Park
# 241  Residential Building (Apartment / Condo)
# 242                              Trailer Park
# 245  Residential Building (Apartment / Condo)
# 246  Residential Building (Apartment / Condo)
# 247                              Trailer Park
# 251                                     Motel
# 252  Residential Building (Apartment / Condo)
# 253                           Vacation Rental
# 258                                     Motel
# ...
#
#     5th Top Venue Category
# 125                  Hotel
#
#
# Cluster 8:
#           Neighborhood 1st Top Venue Category  \
# 3            Fieldston                  Motel
# 7             Woodlawn                  Motel
# 8              Norwood                  Motel
# 9       Williamsbridge                  Motel
# 10          Baychester                  Motel
# 13        Bedford Park                  Motel
# 34             Belmont                  Motel
# 36     North Riverdale                  Motel
# 40         Castle Hill                  Motel
# 41           Olinville                  Motel
# 42      Pelham Gardens                  Motel
# 45            Edenwald                  Motel
# 52      Sheepshead Bay                  Motel
# 65         Cobble Hill                  Motel
# 66     Carroll Gardens                  Motel
# 67            Red Hook                  Motel
# 68             Gowanus                  Motel
# 73       Starrett City                  Motel
# 77     Manhattan Beach                  Motel
# 82     Gerritsen Beach                  Motel
# 84        Clinton Hill                  Motel
# 89          Ocean Hill                  Motel
# 130           Woodside                  Motel
# 132           Elmhurst                  Motel
# 133       Howard Beach                  Motel
# 156          Bellerose                  Motel
# 157  Kew Gardens Hills                  Motel
# 159          Briarwood                  Motel
# 161    Oakland Gardens                  Motel
# 186         Ravenswood                  Motel
# 189        Lefrak City                  Motel
# 260           New Lots                  Motel
# 263      Jamaica Hills                  Motel
# 277  Sunnyside Gardens                  Motel
# 281         Weeksville    Housing Development
#
#                        2nd Top Venue Category  \
# 3                             Assisted Living
# 7                             Assisted Living
# 8    Residential Building (Apartment / Condo)
# 9                         Housing Development
# 10   Residential Building (Apartment / Condo)
# 13   Residential Building (Apartment / Condo)
# 34                        Housing Development
# 36                            Bed & Breakfast
# 40                            Assisted Living
# 41                            Bed & Breakfast
# 42                        Housing Development
# 45                            Bed & Breakfast
# 52                            Assisted Living
# 65                            Bed & Breakfast
# 66                            Bed & Breakfast
# 67                        Housing Development
# 68                            Bed & Breakfast
# 73                        Housing Development
# 77                            Assisted Living
# 82                            Assisted Living
# 84   Residential Building (Apartment / Condo)
# 89                        Housing Development
# 130  Residential Building (Apartment / Condo)
# 132  Residential Building (Apartment / Condo)
# 133                       Housing Development
# 156                           Bed & Breakfast
# 157                           Assisted Living
# 159  Residential Building (Apartment / Condo)
# 161                           Bed & Breakfast
# 186                                     Hotel
# 189  Residential Building (Apartment / Condo)
# 260                       Housing Development
# 263  Residential Building (Apartment / Condo)
# 277  Residential Building (Apartment / Condo)
# 281                                     Motel
#
#                        3rd Top Venue Category  \
# 3    Residential Building (Apartment / Condo)
# 7    Residential Building (Apartment / Condo)
# 8                             Assisted Living
# 9    Residential Building (Apartment / Condo)
# 10                            Vacation Rental
# 13                        Housing Development
# 34   Residential Building (Apartment / Condo)
# 36                            Assisted Living
# 40   Residential Building (Apartment / Condo)
# 41                        Housing Development
# 42   Residential Building (Apartment / Condo)
# 45                        Housing Development
# 52                        Housing Development
# 65   Residential Building (Apartment / Condo)
# 66                                      Hotel
# 67   Residential Building (Apartment / Condo)
# 68   Residential Building (Apartment / Condo)
# 73                            Assisted Living
# 77   Residential Building (Apartment / Condo)
# 82                        Housing Development
# 84                        Housing Development
# 89                            Bed & Breakfast
# 130                                     Hotel
# 132                                     Hotel
# 133                                     Hotel
# 156                       Housing Development
# 157  Residential Building (Apartment / Condo)
# 159                                     Hotel
# 161                       Housing Development
# 186  Residential Building (Apartment / Condo)
# 189                           Assisted Living
# 260                           Assisted Living
# 263                       Housing Development
# 277                                     Hotel
# 281                           Bed & Breakfast
#
#                        4th Top Venue Category 5th Top Venue Category
# 3                         Housing Development        Vacation Rental
# 7                             Vacation Rental           Trailer Park
# 8                         Housing Development        Vacation Rental
# 9                             Vacation Rental           Trailer Park
# 10                               Trailer Park    Housing Development
# 13                                      Hotel        Vacation Rental
# 34                            Assisted Living                  Hotel
# 36   Residential Building (Apartment / Condo)    Housing Development
# 40                        Housing Development                  Hotel
# 41   Residential Building (Apartment / Condo)        Assisted Living
# 42                            Vacation Rental           Trailer Park
# 45   Residential Building (Apartment / Condo)                  Hotel
# 52   Residential Building (Apartment / Condo)                  Hotel
# 65                                      Hotel        Vacation Rental
# 66   Residential Building (Apartment / Condo)    Housing Development
# 67                                      Hotel        Vacation Rental
# 68                                      Hotel        Assisted Living
# 73   Residential Building (Apartment / Condo)                  Hotel
# 77                        Housing Development                  Hotel
# 82   Residential Building (Apartment / Condo)                  Hotel
# 84                                      Hotel        Vacation Rental
# 89   Residential Building (Apartment / Condo)        Assisted Living
# 130                           Vacation Rental           Trailer Park
# 132                           Vacation Rental           Trailer Park
# 133                           Vacation Rental           Trailer Park
# 156                                     Hotel        Vacation Rental
# 157                       Housing Development        Vacation Rental
# 159                       Housing Development        Vacation Rental
# 161  Residential Building (Apartment / Condo)        Vacation Rental
# 186                       Housing Development        Vacation Rental
# 189                                     Hotel    Housing Development
# 260  Residential Building (Apartment / Condo)                  Hotel
# 263                                     Hotel        Vacation Rental
# 277                           Vacation Rental           Trailer Park
# 281  Residential Building (Apartment / Condo)                  Hotel
#
#
# Cluster 9:
#           Neighborhood 1st Top Venue Category  \
# 47         Bensonhurst                 Hostel
# 55       Crown Heights                 Hostel
# 61        Williamsburg                 Hostel
# 80        Borough Park                 Hostel
# 81       Dyker Heights                 Hostel
# 95   East Williamsburg                 Hostel
# 96          North Side                 Hostel
# 97          South Side                 Hostel
# 103   Hamilton Heights                 Hostel
# 105     Central Harlem                 Hostel
# 116            Chelsea                  Hotel
# 138           Flushing                 Hostel
# 139   Long Island City                 Hostel
# 140          Sunnyside                 Hostel
# 173           Steinway                 Hostel
# 210             Travis                 Hostel
# 220          Sunnyside                 Hostel
# 224          Park Hill                 Hostel
# 232      Midland Beach                 Hostel
# 233         Grant City                 Hostel
# 234     New Dorp Beach                 Hostel
# 237    Pleasant Plains                 Hostel
# 243  Heartland Village                 Hostel
# 244            Chelsea                  Hotel
# 254            Concord                 Hostel
# 255       Emerson Hill                 Hostel
# 259     Remsen Village                 Hostel
# 266    Astoria Heights                 Hostel
# 269         Mount Eden                 Hostel
# 272      Hunters Point                 Hostel
# 291       Prince's Bay                 Hostel
# 304       Queensbridge                 Hostel
#
#                        2nd Top Venue Category  \
# 47                            Assisted Living
# 55                                      Motel
# 61                        Housing Development
# 80                            Assisted Living
# 81                                      Motel
# 95                            Bed & Breakfast
# 96   Residential Building (Apartment / Condo)
# 97   Residential Building (Apartment / Condo)
# 103                           Bed & Breakfast
# 105                           Bed & Breakfast
# 116                                    Hostel
# 138                                     Motel
# 139                                     Hotel
# 140                           Bed & Breakfast
# 173                                     Motel
# 210                                     Hotel
# 220                           Bed & Breakfast
# 224                           Bed & Breakfast
# 232                           Assisted Living
# 233                       Housing Development
# 234                       Housing Development
# 237                                     Hotel
# 243                           Assisted Living
# 244                                    Hostel
# 254                           Bed & Breakfast
# 255                           Assisted Living
# 259                       Housing Development
# 266                                     Motel
# 269                           Assisted Living
# 272  Residential Building (Apartment / Condo)
# 291                       Housing Development
# 304                                     Hotel
#
#                        3rd Top Venue Category  \
# 47   Residential Building (Apartment / Condo)
# 55                            Bed & Breakfast
# 61   Residential Building (Apartment / Condo)
# 80   Residential Building (Apartment / Condo)
# 81                            Bed & Breakfast
# 95                            Assisted Living
# 96                                      Hotel
# 97                                      Hotel
# 103  Residential Building (Apartment / Condo)
# 105                       Housing Development
# 116  Residential Building (Apartment / Condo)
# 138                                     Hotel
# 139  Residential Building (Apartment / Condo)
# 140                           Assisted Living
# 173  Residential Building (Apartment / Condo)
# 210                           Vacation Rental
# 220                           Assisted Living
# 224                       Housing Development
# 232                       Housing Development
# 233  Residential Building (Apartment / Condo)
# 234                           Vacation Rental
# 237                           Vacation Rental
# 243  Residential Building (Apartment / Condo)
# 244  Residential Building (Apartment / Condo)
# 254                       Housing Development
# 255                       Housing Development
# 259                           Assisted Living
# 266                                     Hotel
# 269  Residential Building (Apartment / Condo)
# 272                           Assisted Living
# 291                           Vacation Rental
# 304  Residential Building (Apartment / Condo)
#
#                        4th Top Venue Category  \
# 47                            Vacation Rental
# 55   Residential Building (Apartment / Condo)
# 61                                      Hotel
# 80                                      Hotel
# 81   Residential Building (Apartment / Condo)
# 95                        Housing Development
# 96                        Housing Development
# 97                        Housing Development
# 103                       Housing Development
# 105  Residential Building (Apartment / Condo)
# 116                           Vacation Rental
# 138                           Assisted Living
# 139                       Housing Development
# 140  Residential Building (Apartment / Condo)
# 173                       Housing Development
# 210                              Trailer Park
# 220  Residential Building (Apartment / Condo)
# 224  Residential Building (Apartment / Condo)
# 232  Residential Building (Apartment / Condo)
# 233                           Vacation Rental
# 234                              Trailer Park
# 237                              Trailer Park
# 243                           Vacation Rental
# 244                           Vacation Rental
# 254  Residential Building (Apartment / Condo)
# 255  Residential Building (Apartment / Condo)
# 259  Residential Building (Apartment / Condo)
# 266  Residential Building (Apartment / Condo)
# 269                       Housing Development
# 272                                     Hotel
# 291                              Trailer Park
# 304                       Housing Development
#
#                        5th Top Venue Category
# 47                               Trailer Park
# 55                        Housing Development
# 61                            Vacation Rental
# 80                            Vacation Rental
# 81                            Assisted Living
# 95   Residential Building (Apartment / Condo)
# 96                            Vacation Rental
# 97                            Vacation Rental
# 103                           Vacation Rental
# 105                           Assisted Living
# 116                              Trailer Park
# 138  Residential Building (Apartment / Condo)
# 139                           Vacation Rental
# 140                       Housing Development
# 173                                     Hotel
# 210  Residential Building (Apartment / Condo)
# 220                       Housing Development
# 224                                     Hotel
# 232                           Vacation Rental
# 233                              Trailer Park
# 234  Residential Building (Apartment / Condo)
# 237  Residential Building (Apartment / Condo)
# 243                              Trailer Park
# 244                              Trailer Park
# 254                                     Hotel
# 255                                     Hotel
# 259                           Vacation Rental
# 266                           Vacation Rental
# 269                           Vacation Rental
# 272                       Housing Development
# 291  Residential Building (Apartment / Condo)
# 304                           Vacation Rental
